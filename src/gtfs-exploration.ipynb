# %% [markdown]
# Data Exploration of MTS San Diego Static GTFS Data:
# ============================
#
# The purpose of this notebook is to conduct an anaylsis of the relationships between the various data sets provided in MTS San Diego GTFS data. I am aiming to gain an understanding the data they have provided and how it related. Through developing this understanding I will be in a better position predict vehicle arrival time.
#
# ToDo:
#     I need to begin figuring out a method to organize the data in a sensible manner in relation to the problem i am trying to solve.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Uploading static datasets that related to routes, stops, and trips of MTS San Diego into pandas
stops = pd.read_csv('../Data/Static_GTFS_MTS_SD/stops.txt')
stop_times = pd.read_csv('../Data/Static_GTFS_MTS_SD/stop_times.txt')
trips = pd.read_csv('../Data/Static_GTFS_MTS_SD/trips.txt')
routes = pd.read_csv('../Data/Static_GTFS_MTS_SD/routes.txt')
calendar_dates = pd.read_csv('../Data/Static_GTFS_MTS_SD/calendar_dates.txt')
# Out:
# /Users/AlexanderBaker/anaconda/envs/SD_Transit/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# view the fields of the stops txt file
stops.head()
# Out:
#   stop_id                      stop_name   stop_lat    stop_lon  stop_code  \
# 0   10001     Cabrillo National Monument  32.674458 -117.240426    10001.0
# 1   10003           Pearl St & Draper Av  32.839578 -117.276187    10003.0
# 2   10004              Pearl St & Fay Av  32.840128 -117.273810    10004.0
# 3   10006  Torrey Pines Rd & Exchange Pl  32.845847 -117.268673    10006.0
# 4   10007  Torrey Pines Rd & Hillside Dr  32.849312 -117.261752    10007.0
#
#    location_type parent_station  wheelchair_boarding intersection_code  \
# 0              0            NaN                  1.0     M-Special_Loc
# 1              0            NaN                  1.0             N-E/B
# 2              0            NaN                  1.0             N-E/B
# 3              0            NaN                  1.0             N-N/B
# 4              0            NaN                  0.0             N-N/B
#
#   stop_place reference_place         stop_name_short
# ...

# %%
# view the fields of the stop_times txt file
stop_times.head()

"""
    The Data from Stop_Times appear to provide us with the scheduled time of arrive for vehicles for a particular stop?
    I'll need to look into this further. 
    
    Questions:
        1. I don't understand how there are so many stops having the same arrival time and departure time in the same 
        trip. What could cause this? Are they all in the same location?
"""
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence  timepoint  \
# 0  11893600     05:05:00       05:05:00    40846              1          1
# 1  11893600     05:05:00       05:05:00    40739              2          0
# 2  11893600     05:06:00       05:06:00    40434              3          0
# 3  11893600     05:06:00       05:06:00    40429              4          0
# 4  11893600     05:07:00       05:07:00    40989              5          0
#
#    shape_dist_traveled  position_in_block stop_headsign  pickup_type  \
# 0                0.000                0.0           NaN            0
# 1                0.088                1.0           NaN            0
# 2                0.222                2.0           NaN            0
# 3                0.364                3.0           NaN            0
# 4                0.602                4.0           NaN            0
#
#    drop_off_type stop_headsign_short  stop_is_last
# ...

# %%
# view the fields of the trips txt file
trips.head()
# Out:
#   route_id  service_id   trip_id         trip_headsign  direction_id  \
# 0      115       63917  11893750  El Cajon Transit Ctr           0.0
# 1      115       63917  11893751  El Cajon Transit Ctr           0.0
# 2      115       63917  11893752  El Cajon Transit Ctr           0.0
# 3      115       63917  11893753  El Cajon Transit Ctr           0.0
# 4      115       63917  11893754  El Cajon Transit Ctr           0.0
#
#   direction_name block_id  shape_id  wheelchair_accessible  \
# 0           East    11503  115_2_66                      1
# 1           East    11502  115_2_65                      1
# 2           East    11504  115_2_65                      1
# 3           East    11501  115_2_65                      1
# 4           East    11503  115_2_65                      1
#
#    trip_bikes_allowed trip_headsign_short
# 0                   2           El Caj TC
# 1                   2           El Caj TC
# 2                   2           El Caj TC
# ...

# %%
# view the fields of the trips txt file
routes.head()
# Out:
#   route_id route_short_name                           route_long_name  \
# 0        1                1        Hillcrest - Grossmont Transit Ctr.
# 1        2                2         Downtown San Diego - 30th & Adams
# 2        3                3    UCSD Hospital - Euclid Trolley Station
# 3        4                4  12th & Imperial Trolley - Lomita Village
# 4        5                5       Downtown San Diego - Euclid Trolley
#
#    route_type agency_id  route_desc  \
# 0           3       MTS         NaN
# 1           3       MTS         NaN
# 2           3       MTS         NaN
# 3           3       MTS         NaN
# 4           3       MTS         NaN
#
#                                            route_url route_color  \
# 0  http://www.sdmts.com/schedules-real-time?fragm...      000099
# 1  http://www.sdmts.com/schedules-real-time?fragm...      000099
# 2  http://www.sdmts.com/schedules-real-time?fragm...      000099
# ...

# %%
# view the fields of the calendar dates txt file
calendar_dates.head()
# Out:
#    service_id      date  exception_type exception_note schedule_type
# 0       63895  20170129               1          FINAL            SU
# 1       63921  20170129               1          FINAL            SU
# 2       64034  20170129               1     PRODUCTION            SU
# 3       63955  20170129               1  Schedule #105            SU
# 4       63917  20170130               1          FINAL            WD

# %%
# Looking into the routes txt file in further detail. Trying to understand the data.

routes['route_type'].unique()
# .unique() generated 3, 0, and 4 as it's output
# 3 is the most common route so i figured to look for values not equal to 3
routes.loc[routes['route_type'] != 3]

"""
    We now know what the route numbers stand for:
    3 = bus route
    0 = trolley line
    4 = coronado ferry
"""
# Out:
#     route_id        route_short_name             route_long_name  route_type  \
# 41       510  UC San Diego Blue Line  San Ysidro - America Plaza           0
# 42       520             Orange Line   El Cajon - Santa Fe Depot           0
# 43       530              Green Line    Santee - 12th & Imperial           0
# 104      COR                     NaN              Coronado Ferry           4
#
#     agency_id  route_desc                                          route_url  \
# 41        MTS         NaN  http://www.sdmts.com/schedules-real-time?fragm...
# 42        MTS         NaN  http://www.sdmts.com/schedules-real-time?fragm...
# 43        MTS         NaN  http://www.sdmts.com/schedules-real-time?fragm...
# 104       MTS         NaN                 http://www.sdhe.com/coronado-ferry
#
#     route_color route_text_color route_pattern1 route_pattern2
# 41       0000FF           FFFFFF          510SX          510NX
# 42       FF6600           FFFFFF          520EX          520WX
# ...
